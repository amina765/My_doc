# %%
import pandas as pd

# %%
sa = pd.read_csv("C:/Users/Administrator/Downloads/IPL Matches 2008-2020.csv")
sa.head(20)
# Out:
#         id        city        date player_of_match  \
# 0   335982   Bangalore  2008-04-18     BB McCullum
# 1   335983  Chandigarh  2008-04-19      MEK Hussey
# 2   335984       Delhi  2008-04-19     MF Maharoof
# 3   335985      Mumbai  2008-04-20      MV Boucher
# 4   335986     Kolkata  2008-04-20       DJ Hussey
# 5   335987      Jaipur  2008-04-21       SR Watson
# 6   335988   Hyderabad  2008-04-22        V Sehwag
# 7   335989     Chennai  2008-04-23       ML Hayden
# 8   335990   Hyderabad  2008-04-24       YK Pathan
# 9   335991  Chandigarh  2008-04-25   KC Sangakkara
# 10  335992   Bangalore  2008-04-26       SR Watson
# 11  335993     Chennai  2008-04-26        JDP Oram
# 12  335994      Mumbai  2008-04-27    AC Gilchrist
# 13  335995  Chandigarh  2008-04-27       SM Katich
# 14  335996   Bangalore  2008-04-28        MS Dhoni
# 15  335997     Kolkata  2008-04-29   ST Jayasuriya
# 16  335998       Delhi  2008-04-30      GD McGrath
# ...

# %%
sa.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
sa.shape
# Out:
# (816, 17)

# %%
sa.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
sa["player_of_match"]
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
s=sa["date"][sa["player_of_match"]=="JJ Bumrah"]
s
# Out:
# 586    2017-04-12
# 685    2018-05-16
# 702    2019-03-28
# 746    2019-05-02
# 755    2019-05-12
# 812    2020-11-05
# Name: date, dtype: object

# %%
s.count()
# Out:
# np.int64(6)

# %%
sa['id'] = sa['id'].astype('float')
sa.dtypes
# Out:
# id                 float64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
sa["method"] = sa['method'].fillna('dubai')
sa
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# ..         ...         ...         ...             ...
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
wn=sa["winner"][sa["venue"]=="Dubai International Cricket Stadium"]
wn
# Out:
# 402    Royal Challengers Bangalore
# 403               Delhi Daredevils
# 407            Chennai Super Kings
# 409            Sunrisers Hyderabad
# 410            Chennai Super Kings
# 415                Kings XI Punjab
# 417            Sunrisers Hyderabad
# 757                 Delhi Capitals
# 762                Kings XI Punjab
# 768          Kolkata Knight Riders
# 771               Rajasthan Royals
# 774                Kings XI Punjab
# 777            Chennai Super Kings
# 780            Sunrisers Hyderabad
# 781                Kings XI Punjab
# 782            Sunrisers Hyderabad
# 783                 Delhi Capitals
# 786    Royal Challengers Bangalore
# 788            Sunrisers Hyderabad
# 789    Royal Challengers Bangalore
# 792            Chennai Super Kings
# 794          Kolkata Knight Riders
# 798    Royal Challengers Bangalore
# 799                 Mumbai Indians
# 800            Chennai Super Kings
# 803                 Delhi Capitals
# 806            Sunrisers Hyderabad
# ...

# %%
wn.count()
# Out:
# np.int64(33)

# %%
s = sa[(sa["venue"]=="Sheikh Zayed Stadium") & (sa["winner"]=="Mumbai Indians")]
s
# Out:
#             id       city        date player_of_match                 venue  \
# 763  1216499.0  Abu Dhabi  2020-10-28        SA Yadav  Sheikh Zayed Stadium
# 767  1216503.0  Abu Dhabi  2020-10-01      KA Pollard  Sheikh Zayed Stadium
# 772  1216508.0  Abu Dhabi  2020-09-23       RG Sharma  Sheikh Zayed Stadium
# 775  1216511.0  Abu Dhabi  2020-10-06        SA Yadav  Sheikh Zayed Stadium
# 790  1216526.0  Abu Dhabi  2020-10-16       Q de Kock  Sheikh Zayed Stadium
# 793  1216529.0  Abu Dhabi  2020-10-11       Q de Kock  Sheikh Zayed Stadium
#
#      neutral_venue                        team1                  team2  \
# 763              0  Royal Challengers Bangalore         Mumbai Indians
# 767              0               Mumbai Indians        Kings XI Punjab
# 772              0               Mumbai Indians  Kolkata Knight Riders
# 775              0               Mumbai Indians       Rajasthan Royals
# 790              0        Kolkata Knight Riders         Mumbai Indians
# ...

# %%
s.count()
# Out:
# id                 6
# city               6
# date               6
# player_of_match    6
# venue              6
# neutral_venue      6
# team1              6
# team2              6
# toss_winner        6
# toss_decision      6
# winner             6
# result             6
# result_margin      6
# eliminator         6
# method             6
# umpire1            6
# umpire2            6
# dtype: int64

# %%
sa["venue"]
# Out:
# 0                           M Chinnaswamy Stadium
# 1      Punjab Cricket Association Stadium, Mohali
# 2                                Feroz Shah Kotla
# 3                                Wankhede Stadium
# 4                                    Eden Gardens
#                           ...
# 811           Dubai International Cricket Stadium
# 812           Dubai International Cricket Stadium
# 813                          Sheikh Zayed Stadium
# 814                          Sheikh Zayed Stadium
# 815           Dubai International Cricket Stadium
# Name: venue, Length: 816, dtype: object

# %%
ven=sa["venue"].unique()
ven
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
len(ven)
# Out:
# 36

# %%
sa.toss_decision.unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
sa["toss_decision"]=="field"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811     True
# 812     True
# 813     True
# 814    False
# 815    False
# Name: toss_decision, Length: 816, dtype: bool

# %%
s = sa[(sa["toss_decision"]=="field") & (sa["toss_decision"]!="bat")]
print(s)
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 7     335989.0     Chennai  2008-04-23       ML Hayden
# 8     335990.0   Hyderabad  2008-04-24       YK Pathan
# 9     335991.0  Chandigarh  2008-04-25   KC Sangakkara
# 10    335992.0   Bangalore  2008-04-26       SR Watson
# ..         ...         ...         ...             ...
# 801  1216537.0   Abu Dhabi  2020-10-30       BA Stokes
# 803  1216539.0       Dubai  2020-09-25         PP Shaw
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 7               MA Chidambaram Stadium, Chepauk              0
# 8     Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
s.count()
# Out:
# id                 496
# city               488
# date               496
# player_of_match    493
# venue              496
# neutral_venue      496
# team1              496
# team2              496
# toss_winner        496
# toss_decision      496
# winner             493
# result             493
# result_margin      485
# eliminator         493
# method             496
# umpire1            496
# umpire2            496
# dtype: int64

# %%
s = sa[(sa["toss_decision"]=="bat") & (sa["toss_decision"]!="field")]
print(s)
# Out:
#             id        city        date player_of_match  \
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# 5     335987.0      Jaipur  2008-04-21       SR Watson
# ..         ...         ...         ...             ...
# 808  1216544.0       Dubai  2020-10-25      RD Gaikwad
# 809  1216545.0   Abu Dhabi  2020-09-26    Shubman Gill
# 810  1216546.0       Dubai  2020-10-20        S Dhawan
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
s.count()
# Out:
# id                 320
# city               315
# date               320
# player_of_match    319
# venue              320
# neutral_venue      320
# team1              320
# team2              320
# toss_winner        320
# toss_decision      320
# winner             319
# result             319
# result_margin      314
# eliminator         319
# method             320
# umpire1            320
# umpire2            320
# dtype: int64

# %%
sa.result.unique()
# Out:
# array(['runs', 'wickets', 'tie', nan], dtype=object)

# %%
s = sa[(sa["result"]=="runs") & (sa["result"]!="wickets")]
print(s)
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 7     335989.0     Chennai  2008-04-23       ML Hayden
# 9     335991.0  Chandigarh  2008-04-25   KC Sangakkara
# 14    335996.0   Bangalore  2008-04-28        MS Dhoni
# ..         ...         ...         ...             ...
# 804  1216540.0     Sharjah  2020-10-12  AB de Villiers
# 806  1216542.0       Dubai  2020-10-08     JM Bairstow
# 807  1216543.0       Dubai  2020-10-14        A Nortje
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 7               MA Chidambaram Stadium, Chepauk              0
# ...

# %%
s.count()
# Out:
# id                 364
# city               359
# date               364
# player_of_match    364
# venue              364
# neutral_venue      364
# team1              364
# team2              364
# toss_winner        364
# toss_decision      364
# winner             364
# result             364
# result_margin      364
# eliminator         364
# method             364
# umpire1            364
# umpire2            364
# dtype: int64

# %%
s = sa[(sa["result"]=="wickets") & (sa["result"]!="runs")]
print(s)
# Out:
#             id       city        date player_of_match  \
# 2     335984.0      Delhi  2008-04-19     MF Maharoof
# 3     335985.0     Mumbai  2008-04-20      MV Boucher
# 4     335986.0    Kolkata  2008-04-20       DJ Hussey
# 5     335987.0     Jaipur  2008-04-21       SR Watson
# 6     335988.0  Hyderabad  2008-04-22        V Sehwag
# ..         ...        ...         ...             ...
# 808  1216544.0      Dubai  2020-10-25      RD Gaikwad
# 809  1216545.0  Abu Dhabi  2020-09-26    Shubman Gill
# 810  1216546.0      Dubai  2020-10-20        S Dhawan
# 813  1237178.0  Abu Dhabi  2020-11-06   KS Williamson
# 815  1237181.0      Dubai  2020-11-10        TA Boult
#
#                                          venue  neutral_venue  \
# 2                             Feroz Shah Kotla              0
# 3                             Wankhede Stadium              0
# 4                                 Eden Gardens              0
# 5                       Sawai Mansingh Stadium              0
# ...

# %%
s.count()
# Out:
# id                 435
# city               427
# date               435
# player_of_match    435
# venue              435
# neutral_venue      435
# team1              435
# team2              435
# toss_winner        435
# toss_decision      435
# winner             435
# result             435
# result_margin      435
# eliminator         435
# method             435
# umpire1            435
# umpire2            435
# dtype: int64

# %%
s=sa[["id","team1","team2","winner"]]
s
# Out:
#             id                        team1                        team2  \
# 0     335982.0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     335983.0              Kings XI Punjab          Chennai Super Kings
# 2     335984.0             Delhi Daredevils             Rajasthan Royals
# 3     335985.0               Mumbai Indians  Royal Challengers Bangalore
# 4     335986.0        Kolkata Knight Riders              Deccan Chargers
# ..         ...                          ...                          ...
# 811  1216547.0  Royal Challengers Bangalore               Mumbai Indians
# 812  1237177.0               Mumbai Indians               Delhi Capitals
# 813  1237178.0  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814  1237180.0               Delhi Capitals          Sunrisers Hyderabad
# 815  1237181.0               Delhi Capitals               Mumbai Indians
#
#                           winner
# 0          Kolkata Knight Riders
# ...

# %%
s=sa["player_of_match"].value_counts().head(20)
s
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# KA Pollard        11
# V Sehwag          11
# A Mishra          11
# AD Russell        11
# DR Smith          11
# JH Kallis         10
# AT Rayudu         10
# SE Marsh           9
# Name: count, dtype: int64
